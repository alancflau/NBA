# %%
import pandas as pd
url = 'https://raw.githubusercontent.com/jgburgos/ALL-NBA-DNN/master/nba_data_scrape.csv'

df = pd.read_csv(url, index_col = 0)

# %%
pd.set_option('display.max_columns', 500)

# %%
df
# Out:
#                           age   tm  season_start   season   g  gs    mp   fg  \
# player
# Steven Adams               26  OKC          2019  2019-20  58  58  1564  262
# Bam Adebayo                22  MIA          2019  2019-20  65  65  2235  408
# LaMarcus Aldridge          34  SAS          2019  2019-20  53  53  1754  391
# Nickeil Alexander-Walker   21  NOP          2019  2019-20  41   0   501   77
# Grayson Allen              24  MEM          2019  2019-20  30   0   498   79
# ...                       ...  ...           ...      ...  ..  ..   ...  ...
# Orlando Woolridge          30  LAL          1989  1989-90  62   2  1421  306
# Haywoode Workman           24  ATL          1989  1989-90   6   0    16    2
# James Worthy               28  LAL          1989  1989-90  80  80  2960  711
# Danny Young                27  POR          1989  1989-90  82   8  1393  138
# Michael Young              29  LAC          1989  1989-90  45   2   459   92
#
# ...
